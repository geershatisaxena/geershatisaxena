# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
df=pd.read_csv('Census Data.csv')

# %%
df
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'District_code'}>,
#         <AxesSubplot:title={'center':'Population'}>,
#         <AxesSubplot:title={'center':'Male'}>,
#         <AxesSubplot:title={'center':'Female'}>,
#         <AxesSubplot:title={'center':'Literate'}>],
#        [<AxesSubplot:title={'center':'Workers'}>,
#         <AxesSubplot:title={'center':'Male_Workers'}>,
#         <AxesSubplot:title={'center':'Female_Workers'}>,
#         <AxesSubplot:title={'center':'Cultivator_Workers'}>,
#         <AxesSubplot:title={'center':'Agricultural_Workers'}>],
#        [<AxesSubplot:title={'center':'Household_Workers'}>,
#         <AxesSubplot:title={'center':'Hindus'}>,
#         <AxesSubplot:title={'center':'Muslims'}>,
#         <AxesSubplot:title={'center':'Christians'}>,
#         <AxesSubplot:title={'center':'Sikhs'}>],
#        [<AxesSubplot:title={'center':'Buddhists'}>,
#         <AxesSubplot:title={'center':'Jains'}>,
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How to Indexes in DataFrame

# %%
df.style.hide_index()
# Out:
# C:\Users\sarit\AppData\Local\Temp\ipykernel_8956\496160328.py:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_62af4">
#   <thead>
#     <tr>
#       <th id="T_62af4_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_62af4_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_62af4_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_62af4_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_62af4_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_62af4_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_62af4_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_62af4_level0_col7" class="col_heading level0 col7" >Workers</th>
# ...

# %% [markdown]
# ### How can we set the caption/heading on the DataFrame

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.style.set_caption('India Census 2011 Dataset')
# Out:
# <style type="text/css">
# </style>
# <table id="T_543bf">
#   <caption>India Census 2011 Dataset</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_543bf_level0_col0" class="col_heading level0 col0" >District_code</th>
#       <th id="T_543bf_level0_col1" class="col_heading level0 col1" >State_name</th>
#       <th id="T_543bf_level0_col2" class="col_heading level0 col2" >District_name</th>
#       <th id="T_543bf_level0_col3" class="col_heading level0 col3" >Population</th>
#       <th id="T_543bf_level0_col4" class="col_heading level0 col4" >Male</th>
#       <th id="T_543bf_level0_col5" class="col_heading level0 col5" >Female</th>
#       <th id="T_543bf_level0_col6" class="col_heading level0 col6" >Literate</th>
#       <th id="T_543bf_level0_col7" class="col_heading level0 col7" >Workers</th>
#       <th id="T_543bf_level0_col8" class="col_heading level0 col8" >Male_Workers</th>
# ...

# %% [markdown]
# ### Show the records related with districts Lucknow,Kanpur,Delhi

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df['District_name'].isin(['Lucknow','Kanpur','Gorakhpur'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# Name: District_name, Length: 640, dtype: bool

# %%
df[df['District_name'].isin(['Lucknow','Kanpur Nagar','Gorakhpur'])]
# Out:
#      District_code     State_name District_name  Population     Male   Female  \
# 156            157  UTTAR PRADESH       Lucknow     4589838  2394476  2195362
# 163            164  UTTAR PRADESH  Kanpur Nagar     4581268  2459806  2121462
# 187            188  UTTAR PRADESH     Gorakhpur     4440895  2277777  2163118
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 156   3127260  1542806       1226399          316407  ...       20493  23883
# 163   3243022  1572232       1299871          272361  ...       15751  29676
# 187   2700328  1351629       1016876          334753  ...        9662   2123
#
#      Buddhists  Jains  Secondary_Education  Higher_Education  \
# 156       3877   4975               428121            378742
# 163       2733   5710               651228            515772
# 187       2848    460               425913            316166
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# ...

# %% [markdown]
# ### Calculate State Wise

# %% [markdown]
# #### Total Number of Population

# %% [markdown]
# #### Total number of Population with different Religions

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df.groupby('State_name').Population.sum()
# Out:
# State_name
# ANDAMAN AND NICOBAR ISLANDS       380581
# ANDHRA PRADESH                  84580777
# ARUNACHAL PRADESH                1383727
# ASSAM                           31205576
# BIHAR                          104099452
# CHANDIGARH                       1055450
# CHHATTISGARH                    25545198
# DADRA AND NAGAR HAVELI            343709
# DAMAN AND DIU                     243247
# GOA                              1458545
# GUJARAT                         60439692
# HARYANA                         25351462
# HIMACHAL PRADESH                 6864602
# JAMMU AND KASHMIR               12541302
# JHARKHAND                       32988134
# KARNATAKA                       61095297
# KERALA                          33406061
# LAKSHADWEEP                        64473
# MADHYA PRADESH                  72626809
# MAHARASHTRA                    112374333
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# ...

# %%
df.groupby('State_name').Population.sum().sort_values()
# Out:
# State_name
# LAKSHADWEEP                        64473
# DAMAN AND DIU                     243247
# DADRA AND NAGAR HAVELI            343709
# ANDAMAN AND NICOBAR ISLANDS       380581
# SIKKIM                            610577
# CHANDIGARH                       1055450
# MIZORAM                          1097206
# PONDICHERRY                      1247953
# ARUNACHAL PRADESH                1383727
# GOA                              1458545
# NAGALAND                         1978502
# MANIPUR                          2855794
# MEGHALAYA                        2966889
# TRIPURA                          3673917
# HIMACHAL PRADESH                 6864602
# UTTARAKHAND                     10086292
# JAMMU AND KASHMIR               12541302
# NCT OF DELHI                    16787941
# HARYANA                         25351462
# CHHATTISGARH                    25545198
# PUNJAB                          27743338
# ASSAM                           31205576
# ...

# %%
df.groupby('State_name').Population.sum().sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %%
df.groupby('State_name')

# %%
df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum()
# Out:
# C:\Users\sarit\AppData\Local\Temp\ipykernel_8956\3262857727.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum()
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# ...

# %%
df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum().sort_values(by='Hindus')
# Out:
# C:\Users\sarit\AppData\Local\Temp\ipykernel_8956\3430247416.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('State_name')['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains'].sum().sort_values(by='Hindus')
#                                 Hindus   Muslims  Christians     Sikhs  \
# State_name
# LAKSHADWEEP                       1788     62268         317         8
# MIZORAM                          30136     14832      956331       286
# NAGALAND                        173054     48963     1739651      1890
# DAMAN AND DIU                   220150     19277        2820       172
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# MEGHALAYA                       342078    130399     2213027      3045
# SIKKIM                          352662      9867       60522      1868
# ...

# %% [markdown]
# ### How many Male workers are there in Several States

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.State_name
# Out:
# 0                JAMMU AND KASHMIR
# 1                JAMMU AND KASHMIR
# 2                JAMMU AND KASHMIR
# 3                JAMMU AND KASHMIR
# 4                JAMMU AND KASHMIR
#                   ...
# 635                    PONDICHERRY
# 636                    PONDICHERRY
# 637    ANDAMAN AND NICOBAR ISLANDS
# 638    ANDAMAN AND NICOBAR ISLANDS
# 639    ANDAMAN AND NICOBAR ISLANDS
# Name: State_name, Length: 640, dtype: object

# %%
df.State_name == 'UTTAR PRADESH'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 635    False
# 636    False
# 637    False
# 638    False
# 639    False
# Name: State_name, Length: 640, dtype: bool

# %%
df[df.State_name == 'UTTAR PRADESH']
# Out:
#      District_code     State_name                 District_name  Population  \
# 131            132  UTTAR PRADESH                    Saharanpur     3466382
# 132            133  UTTAR PRADESH                 Muzaffarnagar     4143512
# 133            134  UTTAR PRADESH                        Bijnor     3682713
# 134            135  UTTAR PRADESH                     Moradabad     4772006
# 135            136  UTTAR PRADESH                        Rampur     2335819
# ..             ...            ...                           ...         ...
# 197            198  UTTAR PRADESH  Sant Ravidas Nagar (Bhadohi)     1578213
# 198            199  UTTAR PRADESH                      Mirzapur     2496970
# 199            200  UTTAR PRADESH                     Sonbhadra     1862559
# 200            201  UTTAR PRADESH                          Etah     1774480
# 201            202  UTTAR PRADESH               Kanshiram Nagar     1436719
#
# ...

# %%
df[df.State_name == 'MADHYA PRADESH']
# Out:
#      District_code      State_name          District_name  Population  \
# 417            418  MADHYA PRADESH                Sheopur      687861
# 418            419  MADHYA PRADESH                 Morena     1965970
# 419            420  MADHYA PRADESH                  Bhind     1703005
# 420            421  MADHYA PRADESH                Gwalior     2032036
# 421            422  MADHYA PRADESH                  Datia      786754
# 422            423  MADHYA PRADESH               Shivpuri     1726050
# 423            424  MADHYA PRADESH              Tikamgarh     1445166
# 424            425  MADHYA PRADESH             Chhatarpur     1762375
# 425            426  MADHYA PRADESH                  Panna     1016520
# 426            427  MADHYA PRADESH                  Sagar     2378458
# 427            428  MADHYA PRADESH                  Damoh     1264219
# 428            429  MADHYA PRADESH                  Satna     2228935
# ...

# %%
df[df.State_name == 'MAHARASHTRA']
# Out:
#      District_code   State_name    District_name  Population     Male  \
# 496            497  MAHARASHTRA        Nandurbar     1648295   833170
# 497            498  MAHARASHTRA            Dhule     2050862  1054031
# 498            499  MAHARASHTRA          Jalgaon     4229917  2197365
# 499            500  MAHARASHTRA          Buldana     2586258  1337560
# 500            501  MAHARASHTRA            Akola     1813906   932334
# 501            502  MAHARASHTRA           Washim     1197160   620302
# 502            503  MAHARASHTRA         Amravati     2888445  1480768
# 503            504  MAHARASHTRA           Wardha     1300774   668385
# 504            505  MAHARASHTRA           Nagpur     4653570  2384975
# 505            506  MAHARASHTRA         Bhandara     1200334   605520
# 506            507  MAHARASHTRA          Gondiya     1322507   661554
# 507            508  MAHARASHTRA       Gadchiroli     1072942   541328
# ...

# %%
df[df.State_name == 'RAJASTHAN']
# Out:
#      District_code State_name   District_name  Population     Male   Female  \
# 98              99  RAJASTHAN      Ganganagar     1969168  1043340   925828
# 99             100  RAJASTHAN     Hanumangarh     1774692   931184   843508
# 100            101  RAJASTHAN         Bikaner     2363937  1240801  1123136
# 101            102  RAJASTHAN           Churu     2039547  1051446   988101
# 102            103  RAJASTHAN      Jhunjhunun     2137045  1095896  1041149
# 103            104  RAJASTHAN           Alwar     3674179  1939026  1735153
# 104            105  RAJASTHAN       Bharatpur     2548462  1355726  1192736
# 105            106  RAJASTHAN        Dhaulpur     1206516   653647   552869
# 106            107  RAJASTHAN         Karauli     1458248   783639   674609
# 107            108  RAJASTHAN  Sawai Madhopur     1335551   704031   631520
# 108            109  RAJASTHAN           Dausa     1634409   857787   776622
# ...

# %%
df[df.State_name == 'TAMIL NADU']
# Out:
#      District_code  State_name    District_name  Population     Male   Female  \
# 601            602  TAMIL NADU      Thiruvallur     3728104  1876062  1852042
# 602            603  TAMIL NADU          Chennai     4646732  2335844  2310888
# 603            604  TAMIL NADU     Kancheepuram     3998252  2012958  1985294
# 604            605  TAMIL NADU          Vellore     3936331  1961688  1974643
# 605            606  TAMIL NADU   Tiruvannamalai     2464875  1235889  1228986
# 606            607  TAMIL NADU       Viluppuram     3458873  1740819  1718054
# 607            608  TAMIL NADU            Salem     3482056  1781571  1700485
# 608            609  TAMIL NADU         Namakkal     1726601   869280   857321
# 609            610  TAMIL NADU            Erode     2251744  1129868  1121876
# 610            611  TAMIL NADU     The Nilgiris      735394   360143   375251
# 611            612  TAMIL NADU         Dindigul     2159775  1080938  1078837
# ...

# %%
df[df.State_name == 'GUJARAT']
# Out:
#      District_code State_name  District_name  Population     Male   Female  \
# 467            468    GUJARAT        Kachchh     2092371  1096737   995634
# 468            469    GUJARAT   Banas Kantha     3120506  1610379  1510127
# 469            470    GUJARAT          Patan     1343734   694397   649337
# 470            471    GUJARAT       Mahesana     2035064  1056520   978544
# 471            472    GUJARAT   Sabar Kantha     2428589  1244231  1184358
# 472            473    GUJARAT    Gandhinagar     1391753   723864   667889
# 473            474    GUJARAT      Ahmadabad     7214225  3788051  3426174
# 474            475    GUJARAT  Surendranagar     1756268   909917   846351
# 475            476    GUJARAT         Rajkot     3804558  1974445  1830113
# 476            477    GUJARAT       Jamnagar     2160119  1114192  1045927
# 477            478    GUJARAT      Porbandar      585449   300209   285240
# ...

# %%
df[df.State_name == 'UTTARAKHAND']
# Out:
#     District_code   State_name      District_name  Population     Male  \
# 55             56  UTTARAKHAND         Uttarkashi      330086   168597
# 56             57  UTTARAKHAND            Chamoli      391605   193991
# 57             58  UTTARAKHAND        Rudraprayag      242285   114589
# 58             59  UTTARAKHAND      Tehri Garhwal      618931   297986
# 59             60  UTTARAKHAND           Dehradun     1696694   892199
# 60             61  UTTARAKHAND            Garhwal      687271   326829
# 61             62  UTTARAKHAND        Pithoragarh      483439   239306
# 62             63  UTTARAKHAND          Bageshwar      259898   124326
# 63             64  UTTARAKHAND             Almora      622506   291081
# 64             65  UTTARAKHAND          Champawat      259648   131125
# 65             66  UTTARAKHAND           Nainital      954605   493666
# 66             67  UTTARAKHAND  Udham Singh Nagar     1648902   858783
# ...

# %%
df[df.State_name == 'HIMACHAL PRADESH']
# Out:
#     District_code        State_name    District_name  Population    Male  \
# 22             23  HIMACHAL PRADESH           Chamba      519080  261320
# 23             24  HIMACHAL PRADESH           Kangra     1510075  750591
# 24             25  HIMACHAL PRADESH  Lahul AND Spiti       31564   16588
# 25             26  HIMACHAL PRADESH            Kullu      437903  225452
# 26             27  HIMACHAL PRADESH            Mandi      999777  498065
# 27             28  HIMACHAL PRADESH         Hamirpur      454768  217070
# 28             29  HIMACHAL PRADESH              Una      521173  263692
# 29             30  HIMACHAL PRADESH         Bilaspur      381956  192764
# 30             31  HIMACHAL PRADESH            Solan      580320  308754
# 31             32  HIMACHAL PRADESH          Sirmaur      529855  276289
# 32             33  HIMACHAL PRADESH           Shimla      814010  425039
# 33             34  HIMACHAL PRADESH          Kinnaur       84121   46249
#
# ...

# %%
df[df.State_name == 'KERALA']
# Out:
#      District_code State_name       District_name  Population     Male  \
# 587            588     KERALA           Kasaragod     1307375   628613
# 588            589     KERALA              Kannur     2523003  1181446
# 589            590     KERALA             Wayanad      817420   401684
# 590            591     KERALA           Kozhikode     3086293  1470942
# 591            592     KERALA          Malappuram     4112920  1960328
# 592            593     KERALA            Palakkad     2809934  1359478
# 593            594     KERALA            Thrissur     3121200  1480763
# 594            595     KERALA           Ernakulam     3282388  1619557
# 595            596     KERALA              Idukki     1108974   552808
# 596            597     KERALA            Kottayam     1974551   968289
# 597            598     KERALA           Alappuzha     2127789  1013142
# 598            599     KERALA      Pathanamthitta     1197412   561716
# ...

# %%
df[df.State_name == 'ANDHRA PRADESH']
# Out:
#      District_code      State_name                District_name  Population  \
# 531            532  ANDHRA PRADESH                     Adilabad     2741239
# 532            533  ANDHRA PRADESH                    Nizamabad     2551335
# 533            534  ANDHRA PRADESH                   Karimnagar     3776269
# 534            535  ANDHRA PRADESH                        Medak     3033288
# 535            536  ANDHRA PRADESH                    Hyderabad     3943323
# 536            537  ANDHRA PRADESH                   Rangareddy     5296741
# 537            538  ANDHRA PRADESH                  Mahbubnagar     4053028
# 538            539  ANDHRA PRADESH                     Nalgonda     3488809
# 539            540  ANDHRA PRADESH                     Warangal     3512576
# 540            541  ANDHRA PRADESH                      Khammam     2797370
# 541            542  ANDHRA PRADESH                   Srikakulam     2703114
# ...

# %%
df[df.State_name == 'ORISSA']
# Out:
#      District_code State_name   District_name  Population     Male   Female  \
# 369            370     ORISSA         Bargarh     1481255   749161   732094
# 370            371     ORISSA      Jharsuguda      579505   296690   282815
# 371            372     ORISSA       Sambalpur     1041099   526877   514222
# 372            373     ORISSA        Debagarh      312520   158230   154290
# 373            374     ORISSA      Sundargarh     2093437  1061147  1032290
# 374            375     ORISSA       Kendujhar     1801733   906487   895246
# 375            376     ORISSA      Mayurbhanj     2519738  1256213  1263525
# 376            377     ORISSA       Baleshwar     2320529  1185787  1134742
# 377            378     ORISSA         Bhadrak     1506337   760260   746077
# 378            379     ORISSA      Kendrapara     1440361   717814   722547
# 379            380     ORISSA  Jagatsinghapur     1136971   577865   559106
# ...

# %%
df[df.State_name == 'UTTAR PRADESH']['Male_Workers'].sum()
# Out:
# 49846762

# %%
df[df.State_name == 'MADHYA PRADESH']['Male_Workers'].sum()
# Out:
# 20146970

# %%
df[df.State_name == 'MAHARASHTRA']['Male_Workers'].sum()
# Out:
# 32616875

# %%
df[df.State_name == 'RAJASTHAN']['Male_Workers'].sum()
# Out:
# 18297076

# %%
df[df.State_name == 'TAMIL NADU']['Male_Workers'].sum()
# Out:
# 21434978

# %%
df[df.State_name == 'GUJARAT']['Male_Workers'].sum()
# Out:
# 18000914

# %%
df[df.State_name == 'UTTARAKHAND']['Male_Workers'].sum()
# Out:
# 2551921

# %%
df[df.State_name == 'HIMACHAL PRADESH']['Male_Workers'].sum()
# Out:
# 2043373

# %%
df[df.State_name == 'KERALA']['Male_Workers'].sum()
# Out:
# 8451569

# %%
df[df.State_name == 'ANDHRA PRADESH']['Male_Workers'].sum()
# Out:
# 24185595

# %%
df[df.State_name == 'ORISSA']['Male_Workers'].sum()
# Out:
# 11902655

# %% [markdown]
# ### How to set a column as index  of the DataFrame

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.set_index('District_code')
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ### Add a Suffix to the column names

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %%
df.add_suffix('_Indian')
# Out:
#      District_code_Indian            State_name_Indian  \
# 0                       1            JAMMU AND KASHMIR
# 1                       2            JAMMU AND KASHMIR
# 2                       3            JAMMU AND KASHMIR
# 3                       4            JAMMU AND KASHMIR
# 4                       5            JAMMU AND KASHMIR
# ..                    ...                          ...
# 635                   636                  PONDICHERRY
# 636                   637                  PONDICHERRY
# 637                   638  ANDAMAN AND NICOBAR ISLANDS
# 638                   639  ANDAMAN AND NICOBAR ISLANDS
# 639                   640  ANDAMAN AND NICOBAR ISLANDS
#
#           District_name_Indian  Population_Indian  Male_Indian  Female_Indian  \
# 0                      Kupwara             870354       474190         396164
# 1                       Badgam             753745       398041         355704
# ...

# %% [markdown]
# ### Add a Prefix to the column names

# %%
df.add_prefix('Indian')
# Out:
#      IndianDistrict_code             IndianState_name  \
# 0                      1            JAMMU AND KASHMIR
# 1                      2            JAMMU AND KASHMIR
# 2                      3            JAMMU AND KASHMIR
# 3                      4            JAMMU AND KASHMIR
# 4                      5            JAMMU AND KASHMIR
# ..                   ...                          ...
# 635                  636                  PONDICHERRY
# 636                  637                  PONDICHERRY
# 637                  638  ANDAMAN AND NICOBAR ISLANDS
# 638                  639  ANDAMAN AND NICOBAR ISLANDS
# 639                  640  ANDAMAN AND NICOBAR ISLANDS
#
#            IndianDistrict_name  IndianPopulation  IndianMale  IndianFemale  \
# 0                      Kupwara            870354      474190        396164
# 1                       Badgam            753745      398041        355704
# 2                  Leh(Ladakh)            133487       78971         54516
# ...

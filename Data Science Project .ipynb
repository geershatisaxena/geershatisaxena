# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
df=pd.read_csv('data_science.csv')
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
plt.figure(figsize=(10,10))
plt.bar(x= df.index,height=df.job_title,color='g')
plt.xticks(rotation=-20,color='k')
# Out:
# (array([-100.,    0.,  100.,  200.,  300.,  400.,  500.,  600.,  700.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df.drop(['Unnamed: 0','salary'],axis=1,inplace=True)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df1=df.groupby('work_year')['salary_in_usd'].mean()

# %%
df1
# Out:
# work_year
# 2020     95813.000000
# 2021     99853.792627
# 2022    124522.006289
# Name: salary_in_usd, dtype: float64

# %%
df1=df.groupby('work_year')['salary_in_usd'].mean().round(2)

# %%
df1
# Out:
# work_year
# 2020     95813.00
# 2021     99853.79
# 2022    124522.01
# Name: salary_in_usd, dtype: float64

# %%
df1.plot(kind='bar',color='seagreen')
# Out:
# <AxesSubplot:xlabel='work_year'>

# %%
df1.index
# Out:
# Int64Index([2020, 2021, 2022], dtype='int64', name='work_year')

# %%
df1.values
# Out:
# array([ 95813.  ,  99853.79, 124522.01])

# %%
data={'work_year':df1.index,'average_salary':df1.values}
df1=pd.DataFrame(data)
df1
# Out:
#    work_year  average_salary
# 0       2020        95813.00
# 1       2021        99853.79
# 2       2022       124522.01

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          79833                 DE             0
# 1             USD         260000                 JP             0
# 2             GBP         109024                 GB            50
# 3             USD          20000                 HN             0
# 4             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# ...

# %%
df1['average_salary']=(df1['average_salary']/100).round(2)

# %%
df1
# Out:
#    work_year  average_salary
# 0       2020          958.13
# 1       2021          998.54
# 2       2022         1245.22

# %%
ax = df1.plot(kind='bar',x='work_year',y='average_salary',legend=True,color='crimson')
plt.xlabel('Work Year')
plt.ylabel('Average Salary')
plt.title('Average Salaries by Year',color='k')
# Out:
# Text(0.5, 1.0, 'Average Salaries by Year')

# %%
ax = df1.plot(kind='bar',x='work_year',y='average_salary',legend=True,color='mediumvioletred')
ax.bar_label(ax.containers[0],labels= df1['average_salary'].map('{:.2f}k'.format))
plt.xlabel('Work Year')
plt.ylabel('Average Salary')
plt.title('Average Salaries by Year',color='k')
# Out:
# Text(0.5, 1.0, 'Average Salaries by Year')

# %%
ax = df1.plot(kind='bar',x='work_year',y='average_salary',legend=True,color='cadetblue')
ax.bar_label(ax.containers[0],labels= df1['average_salary'].map('{:.2f}k'.format))
plt.subplots_adjust(top=1.2)
ax.legend(['Average Salary'],loc = 'upper left')
plt.xlabel('Work Year')
plt.ylabel('Average Salary')
plt.title('Average Salaries by Year',color='k')
# Out:
# Text(0.5, 1.0, 'Average Salaries by Year')

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df2=df.remote_ratio.value_counts()
df2
# Out:
# 100    381
# 0      127
# 50      99
# Name: remote_ratio, dtype: int64

# %%
df2.plot(marker='o',color='g')
# Out:
# <AxesSubplot:>

# %%
values=df2.to_list()

# %%
labels = ['Fully Remote','No Remote','Partially Remote']

# %%
z=plt.bar(labels,values,width=0.5,color='m')

# %%
z=plt.bar(labels,values,width=0.5,color='g')
plt.bar_label(z,labels=values)
# Out:
# [Text(0, 0, '381'), Text(0, 0, '127'), Text(0, 0, '99')]

# %%
values
# Out:
# [381, 127, 99]

# %%
z=plt.bar(labels,values,width=0.5,color='yellow')
plt.bar_label(z,labels=values)
plt.title('Employees in Remote Position')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df3=df.company_size.value_counts()
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df3.index
# Out:
# Index(['M', 'L', 'S'], dtype='object')

# %%
df3.plot(color='r',marker='o')
# Out:
# <AxesSubplot:>

# %%
df3.index.to_list()
# Out:
# ['M', 'L', 'S']

# %%
df3.index.to_list()
# Out:
# ['M', 'L', 'S']

# %%
values2 = df3.values

# %%
values2
# Out:
# array([326, 198,  83], dtype=int64)

# %%
labels_for_company=['Large','Medium','Small']

# %%
labels_for_company
# Out:
# ['Large', 'Medium', 'Small']

# %%
plt.figure(figsize=(13,6))
plt.pie(x= values2,labels=None)
plt.legend(labels_for_company)
plt.title('Company Titles')
# Out:
# Text(0.5, 1.0, 'Company Titles')

# %%
plt.figure(figsize=(13,6))
plt.pie(x=values2, labels=None, colors=['r','k','c'])
plt.legend(labels_for_company)
plt.title('Company Titles')
# Out:
# Text(0.5, 1.0, 'Company Titles')

# %%
plt.figure(figsize=(13,6))
plt.pie(x=values2, labels=values2, colors=['olive','yellow','peru'],autopct='%1.1f%%',shadow=True)
plt.legend(labels_for_company)
plt.title('Company Titles')
# Out:
# Text(0.5, 1.0, 'Company Titles')

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df.job_title.value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df4=df.job_title.value_counts()[:5]

# %%
df4
# Out:
# Data Scientist               143
# Data Engineer                132
# Data Analyst                  97
# Machine Learning Engineer     41
# Research Scientist            16
# Name: job_title, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(x= df4.index,height=df4.values,color='palevioletred')
plt.title('Top 5 Job Titles')
plt.ylabel('Count')
plt.xticks(rotation=30)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df4.index,y=df4.values,palette ='viridis')
plt.title('Top 5 Job Titles')
plt.ylabel('Count')
plt.xticks(rotation=-20)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Data Scientist'),
#   Text(1, 0, 'Data Engineer'),
#   Text(2, 0, 'Data Analyst'),
#   Text(3, 0, 'Machine Learning Engineer'),
#   Text(4, 0, 'Research Scientist')])

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df5=df[['salary_in_usd','company_size']]

# %%
df5
# Out:
#      salary_in_usd company_size
# 0            79833            L
# 1           260000            S
# 2           109024            M
# 3            20000            S
# 4           150000            L
# ..             ...          ...
# 602         154000            M
# 603         126000            M
# 604         129000            M
# 605         150000            M
# 606         200000            L
#
# [607 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
S=df5[df5['company_size']=='S']
M=df5[df5['company_size']=='M']
L=df5[df5['company_size']=='L']

# %%
labels=['Medium','Large','Small']
labels
# Out:
# ['Medium', 'Large', 'Small']

# %%
sal_mean=[S['salary_in_usd'].mean(),
          M['salary_in_usd'].mean(),
         L['salary_in_usd'].mean()]

# %%
sal_mean #finding the mean of salary
# Out:
# [77632.67469879518, 116905.46625766871, 119242.99494949495]

# %%
label_change = np.round([x/100 for x in sal_mean], 2)

# %%
label_change
# Out:
# array([ 776.33, 1169.05, 1192.43])

# %%
label_change=list(map(str,label_change))
label_change=[x + 'k' for x in label_change]
label_change
# Out:
# ['776.33k', '1169.05k', '1192.43k']

# %%
z=plt.bar(labels,sal_mean,color='seagreen')
plt.bar_label(z,label_change,alpha=0.8)
# Out:
# [Text(0, 0, '776.33k'), Text(0, 0, '1169.05k'), Text(0, 0, '1192.43k')]

# %%
z=plt.bar(labels,sal_mean,color='indigo')
plt.bar_label(z,label_change,alpha=0.8)
plt.title('Distribution of Salary by Company Size')
plt.xlabel('Size of Company')
plt.ylabel('Salary in USD')
# Out:
# Text(0, 0.5, 'Salary in USD')

# %%
S
# Out:
#      salary_in_usd company_size
# 1           260000            S
# 3            20000            S
# 6           190000            S
# 9           125000            S
# 10           51321            S
# ..             ...          ...
# 510         150000            S
# 512          65000            S
# 513          71444            S
# 515          48000            S
# 522          20000            S
#
# [83 rows x 2 columns]

# %%
sns.histplot(S['salary_in_usd'],label="Small",kde=True,color='darkgreen')
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='Count'>

# %%
M
# Out:
#      salary_in_usd company_size
# 2           109024            M
# 12           39916            M
# 18            5707            M
# 19           56000            M
# 20           43331            M
# ..             ...          ...
# 601          52000            M
# 602         154000            M
# 603         126000            M
# 604         129000            M
# 605         150000            M
#
# [326 rows x 2 columns]

# %%
sns.histplot(M['salary_in_usd'],label="Medium",kde=True,color='olive')
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='Count'>

# %%
L
# Out:
#      salary_in_usd company_size
# 0            79833            L
# 4           150000            L
# 5            72000            L
# 7            35735            L
# 8           135000            L
# ..             ...          ...
# 524         135000            L
# 525         177000            L
# 550         205300            L
# 551         140400            L
# 606         200000            L
#
# [198 rows x 2 columns]

# %%
sns.histplot(L['salary_in_usd'],label="Large",kde=True,color='r')
# Out:
# <AxesSubplot:xlabel='salary_in_usd', ylabel='Count'>

# %%
sns.histplot(S['salary_in_usd'],label="Small",kde=True)
sns.histplot(M['salary_in_usd'],label="Medium",kde=True)
sns.histplot(L['salary_in_usd'],label="Large",kde=True)

plt.title('Distribution of Salary by Company Size')
plt.xlabel('Salary in USD')
plt.ylabel('Salary in USD')
# Out:
# Text(0, 0.5, 'Salary in USD')

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df6=df.experience_level.value_counts()

# %%
df6
# Out:
# Seniors        280
# Middle         213
# Entry Level     88
# Executive       26
# Name: experience_level, dtype: int64

# %%
df6.index
# Out:
# Index(['Seniors', 'Middle', 'Entry Level', 'Executive'], dtype='object')

# %%
df6.index.to_list()
# Out:
# ['SE', 'MI', 'EN', 'EX']

# %%
#df['experience_level'].replase('SE','Senior',inplace=True)

# %%
exp_map={
    'SE':'Seniors',
    'MI':'Middle',
    'EN':'Entry Level',
    'EX':'Executive'}

# %%
df['experience_level'].replace(exp_map,inplace=True)

# %%
labels= df6.index.to_list()

# %%
labels
# Out:
# ['Seniors', 'Middle', 'Entry Level', 'Executive']

# %%
values=df6.values

# %%
values
# Out:
# array([280, 213,  88,  26], dtype=int64)

# %%
plt.figure(figsize=(5,10))
plt.pie(x =values,labels =labels,autopct='%1.2f%%', shadow=True)
plt.title('Experience Level of Employees')
# Out:
# Text(0.5, 1.0, 'Experience Level of Employees')

# %%
plt.figure(figsize=(5,10))
plt.pie(x =values,labels =labels,autopct='%1.2f%%', shadow=True,
        colors=['seagreen','gold','mediumspringgreen','sandybrown'])
plt.title('Experience Level of Employees')
# Out:
# Text(0.5, 1.0, 'Experience Level of Employees')

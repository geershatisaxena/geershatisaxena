# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing Dataset

# %%
data=pd.read_csv('Netflix.csv')

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### Getting some information about dataset

# %%
data.head(20)
# Out:
#    Show_Id Category   Title              Director  \
# 0       s1  TV Show      3%                   NaN
# 1       s2    Movie   07:19     Jorge Michel Grau
# 2       s3    Movie   23:59          Gilbert Chan
# 3       s4    Movie       9           Shane Acker
# 4       s5    Movie      21        Robert Luketic
# 5       s6  TV Show      46           Serdar Akar
# 6       s7    Movie     122       Yasir Al Yasiri
# 7       s8    Movie     187        Kevin Reynolds
# 8       s9    Movie     706         Shravan Kumar
# 9      s10    Movie    1920          Vikram Bhatt
# 10     s11    Movie    1922          Zak Hilditch
# 11     s12  TV Show    1983                   NaN
# 12     s13  TV Show    1994  Diego Enrique Osorno
# 13     s14    Movie   2,215   Nottapon Boonprakob
# 14     s15    Movie    3022            John Suits
# 15     s16    Movie  Oct-01        Kunle Afolayan
# 16     s17  TV Show  Feb-09                   NaN
# 17     s18    Movie  22-Jul       Paul Greengrass
# ...

# %%
data.tail(10)
# Out:
#      Show_Id Category                                    Title  \
# 7779   s7778  TV Show                              Zombie Dumb
# 7780   s7779    Movie                               Zombieland
# 7781   s7780  TV Show                                Zona Rosa
# 7782   s7781    Movie                                      Zoo
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 7779              NaN                                                NaN
# 7780  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.size
# Out:
# 85679

# %%
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Is there any Duplicate Record in this dataset? If yes then remove it

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.shape
# Out:
# (7789, 11)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.shape
# Out:
# (7787, 11)

# %% [markdown]
# ### Is there any null value in any column ? Show with a heatmap

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#Heatmap
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### For some Indian Shows what is the Show Id and who is the Director of this show?

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data['Title']
# Out:
# 0                                            3%
# 1                                         07:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7784                                       Zozo
# 7785                                     Zubaan
# 7786                          Zulu Man in Japan
# 7787                      Zumbo's Just Desserts
# 7788    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: Title, Length: 7787, dtype: object

# %%
data['Title'].isin(['Om Shanti Om'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].isin(['Om Shanti Om'])]
# Out:
#      Show_Id Category         Title    Director  \
# 4608   s4609    Movie  Om Shanti Om  Farah Khan
#
#                                                    Cast Country  \
# 4608  Shah Rukh Khan, Deepika Padukone, Shreyas Talp...   India
#
#        Release_Date Rating Duration                                    Type  \
# 4608  April 1, 2018  TV-14  169 min  Comedies, Dramas, International Movies
#
#                                             Description
# 4608  Reincarnated 30 years after being killed in a ...

# %%
data['Title'].isin(['Rang De Basanti'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].isin(['Rang De Basanti'])]
# Out:
#      Show_Id Category            Title                 Director  \
# 5098   s5098    Movie  Rang De Basanti  Rakeysh Omprakash Mehra
#
#                                                    Cast Country  \
# 5098  Aamir Khan, Siddharth, Atul Kulkarni, Sharman ...   India
#
#         Release_Date Rating Duration                          Type  \
# 5098  August 2, 2018  TV-14  159 min  Dramas, International Movies
#
#                                             Description
# 5098  An idealistic English filmmaker casts a group ...

# %%
data['Title'].isin(['Happy New Year'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
data[data['Title'].isin(['Happy New Year'])]
# Out:
#      Show_Id Category           Title    Director  \
# 2613   s2614    Movie  Happy New Year  Farah Khan
#
#                                                    Cast Country  \
# 2613  Shah Rukh Khan, Deepika Padukone, Abhishek Bac...   India
#
#           Release_Date Rating Duration                                  Type  \
# 2613  February 1, 2017  TV-14  179 min  Action & Adventure, Comedies, Dramas
#
#                                             Description
# 2613  A revenge-seeking diamond thief gathers a ragt...

# %%
data[data['Title'].isin(['Tamasha'])]
# Out:
#      Show_Id Category    Title    Director  \
# 5979   s5979    Movie  Tamasha  Imtiaz Ali
#
#                                                    Cast Country  \
# 5979  Ranbir Kapoor, Deepika Padukone, Piyush Mishra...   India
#
#         Release_Date Rating Duration  \
# 5979  August 2, 2018  TV-14  133 min
#
#                                                Type  \
# 5979  Dramas, International Movies, Romantic Movies
#
#                                             Description
# 5979  Meeting while on vacation, Ved and Tara sense ...

# %%
data[data['Title'].isin(['Made in China'])]
# Out:
#      Show_Id Category          Title       Director  \
# 3846   s3847    Movie  Made in China  Mikhil Musale
#
#                                                    Cast Country  \
# 3846  Rajkummar Rao, Boman Irani, Mouni Roy, Sumeet ...   India
#
#           Release_Date Rating Duration  \
# 3846  January 12, 2020  TV-MA  128 min
#
#                                         Type  \
# 3846  Comedies, Dramas, International Movies
#
#                                             Description
# 3846  After a trip to China, a struggling entreprene...

# %%
data[data['Title'].isin(['Lakshya'])]
# Out:
#      Show_Id Category    Title       Director  \
# 3524   s3525    Movie  Lakshya  Farhan Akhtar
#
#                                                    Cast Country  \
# 3524  Amitabh Bachchan, Hrithik Roshan, Preity Zinta...   India
#
#            Release_Date Rating Duration  \
# 3524  December 15, 2019  TV-PG  185 min
#
#                                                   Type  \
# 3524  Action & Adventure, Dramas, International Movies
#
#                                             Description
# 3524  After dropping out of the army, a spoiled teen...

# %%
data[data['Title'].isin(['Zero'])]
# Out:
#      Show_Id Category Title    Director  \
# 7766   s7765    Movie  Zero  Aanand Rai
#
#                                                    Cast Country  Release_Date  \
# 7766  Shah Rukh Khan, Anushka Sharma, Katrina Kaif, ...   India  May 21, 2019
#
#      Rating Duration                                    Type  \
# 7766  TV-14  159 min  Comedies, Dramas, International Movies
#
#                                             Description
# 7766  Through his relationships with two wildly diff...

# %%
data[data['Title'].isin(['Main Hoon Na'])]
# Out:
#      Show_Id Category         Title    Director  \
# 3872   s3873    Movie  Main Hoon Na  Farah Khan
#
#                                                    Cast Country  \
# 3872  Shah Rukh Khan, Sunil Shetty, Sushmita Sen, Za...   India
#
#        Release_Date Rating Duration                                  Type  \
# 3872  April 1, 2018  TV-14  171 min  Action & Adventure, Comedies, Dramas
#
#                                             Description
# 3872  Major Ram Prasad Sharma yearns to see project ...

# %%
data[data['Title'].isin(['Dilwale'])]
# Out:
#      Show_Id Category    Title      Director  \
# 1764   s1765    Movie  Dilwale  Rohit Shetty
#
#                                                    Cast Country  \
# 1764  Shah Rukh Khan, Kajol, Kriti Sanon, Kabir Bedi...   India
#
#           Release_Date Rating Duration  \
# 1764  February 1, 2017  TV-PG  154 min
#
#                                                   Type  \
# 1764  Action & Adventure, Dramas, International Movies
#
#                                             Description
# 1764  A young couple falls in love, but conflicting ...

# %%
data[data['Title'].isin(['Kuch Kuch Hota Hai'])]
# Out:
#      Show_Id Category               Title     Director  \
# 3460   s3461    Movie  Kuch Kuch Hota Hai  Karan Johar
#
#                                                    Cast Country  \
# 3460  Shah Rukh Khan, Kajol, Rani Mukerji, Farida Ja...   India
#
#        Release_Date Rating Duration                                    Type  \
# 3460  April 1, 2020  TV-14  185 min  Comedies, Dramas, International Movies
#
#                                             Description
# 3460  Per her mother’s last wish, a girl sets out to...

# %%
data[data['Title'].isin(['PK'])]
# Out:
#      Show_Id Category Title         Director  \
# 4873   s4873    Movie    PK  Rajkumar Hirani
#
#                                                    Cast Country  \
# 4873  Aamir Khan, Anuskha Sharma, Sanjay Dutt, Saura...   India
#
#            Release_Date Rating Duration  \
# 4873  September 6, 2018  TV-14  146 min
#
#                                         Type  \
# 4873  Comedies, Dramas, International Movies
#
#                                             Description
# 4873  Aamir Khan teams with director Rajkumar Hirani...

# %%
data[data['Title'].isin(['Sanju'])]
# Out:
#      Show_Id Category  Title         Director  \
# 5378   s5378    Movie  Sanju  Rajkumar Hirani
#
#                                                    Cast Country  \
# 5378  Ranbir Kapoor, Vicky Kaushal, Paresh Rawal, So...   India
#
#           Release_Date Rating Duration                          Type  \
# 5378  October 15, 2018  TV-MA  159 min  Dramas, International Movies
#
#                                             Description
# 5378  From the depths of addiction to the heights of...

# %%
data[data['Title'].isin(['1920'])]
# Out:
#   Show_Id Category Title      Director  \
# 9     s10    Movie  1920  Vikram Bhatt
#
#                                                 Cast Country  \
# 9  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India
#
#         Release_Date Rating Duration  \
# 9  December 15, 2017  TV-MA  143 min
#
#                                              Type  \
# 9  Horror Movies, International Movies, Thrillers
#
#                                          Description
# 9  An architect and his wife move into a castle t...

# %%
data[data['Title'].isin(['706'])]
# Out:
#   Show_Id Category Title       Director  \
# 8      s9    Movie   706  Shravan Kumar
#
#                                                 Cast Country   Release_Date  \
# 8  Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India  April 1, 2019
#
#   Rating Duration                                 Type  \
# 8  TV-14  118 min  Horror Movies, International Movies
#
#                                          Description
# 8  When a doctor goes missing, his psychiatrist w...

# %%
data[data['Title'].isin(['15-Aug'])]
# Out:
#    Show_Id Category   Title            Director  \
# 18     s19    Movie  15-Aug  Swapnaneel Jayakar
#
#                                                  Cast Country    Release_Date  \
# 18  Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...   India  March 29, 2019
#
#    Rating Duration                                  Type  \
# 18  TV-14  124 min  Comedies, Dramas, Independent Movies
#
#                                           Description
# 18  On India's Independence Day, a zany mishap in ...

# %%
data[data['Title'].isin(['2 States'])]
# Out:
#    Show_Id Category     Title         Director  \
# 78     s79    Movie  2 States  Abhishek Varman
#
#                                                  Cast Country    Release_Date  \
# 78  Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...   India  August 4, 2018
#
#    Rating Duration                                    Type  \
# 78  TV-PG  143 min  Comedies, Dramas, International Movies
#
#                                           Description
# 78  Graduate students Krish and Ananya hope to win...

# %%
data[data['Title'].isin(['3 Idiots'])]
# Out:
#     Show_Id Category     Title         Director  \
# 100    s101    Movie  3 Idiots  Rajkumar Hirani
#
#                                                   Cast Country  \
# 100  Aamir Khan, Kareena Kapoor, Madhavan, Sharman ...   India
#
#        Release_Date Rating Duration                                    Type  \
# 100  August 1, 2019  PG-13  164 min  Comedies, Dramas, International Movies
#
#                                            Description
# 100  While attending one of India's premier college...

# %%
data[data['Title'].isin(['7 Khoon Maaf'])]
# Out:
#     Show_Id Category         Title         Director  \
# 136    s137    Movie  7 Khoon Maaf  Vishal Bhardwaj
#
#                                                   Cast Country  \
# 136  Priyanka Chopra, Neil Nitin Mukesh, John Abrah...   India
#
#        Release_Date Rating Duration                                     Type  \
# 136  August 2, 2018  TV-MA  148 min  Dramas, International Movies, Thrillers
#
#                                            Description
# 136  Spiced liberally with black comedy, this Bolly...

# %%
data[data['Title'].isin(['A Flying Jatt'])]
# Out:
#     Show_Id Category          Title      Director  \
# 172    s173    Movie  A Flying Jatt  Remo D'Souza
#
#                                                   Cast Country  \
# 172  Tiger Shroff, Jacqueline Fernandez, Nathan Jon...   India
#
#           Release_Date Rating Duration  \
# 172  November 15, 2017  TV-14  142 min
#
#                                                   Type  \
# 172  Action & Adventure, International Movies, Sci-...
#
#                                            Description
# 172  A timid man gets unexpected superpowers while ...

# %%
data[data['Title'].isin(['ABCD 2'])]
# Out:
#     Show_Id Category   Title      Director  \
# 278    s279    Movie  ABCD 2  Remo D'Souza
#
#                                                   Cast Country  \
# 278  Prabhu Deva, Varun Dhawan, Shraddha Kapoor, La...   India
#
#          Release_Date Rating Duration  \
# 278  November 1, 2018  TV-14  146 min
#
#                                                Type  \
# 278  Dramas, International Movies, Music & Musicals
#
#                                            Description
# 278  After being accused of cheating on a reality T...

# %%
data[data['Title'].isin(['A Wednesday'])]
# Out:
#     Show_Id Category        Title       Director  \
# 251    s252    Movie  A Wednesday  Neeraj Pandey
#
#                                                   Cast Country  \
# 251  Anupam Kher, Naseeruddin Shah, Jimmy Shergill,...   India
#
#          Release_Date Rating Duration  \
# 251  November 1, 2018  TV-MA  103 min
#
#                                                  Type  \
# 251  Action & Adventure, Dramas, International Movies
#
#                                            Description
# 251  After receiving an anonymous tip about a bomb,...

# %%
data[data['Title'].isin(['Aarakshan'])]
# Out:
#     Show_Id Category      Title     Director  \
# 271    s272    Movie  Aarakshan  Prakash Jha
#
#                                                   Cast Country  \
# 271  Amitabh Bachchan, Saif Ali Khan, Manoj Bajpaye...   India
#
#           Release_Date Rating Duration                          Type  \
# 271  December 31, 2019  TV-14  164 min  Dramas, International Movies
#
#                                            Description
# 271  The decision by India's supreme court to estab...

# %%
data[data['Title'].isin(['Action Replayy'])]
# Out:
#     Show_Id Category           Title             Director  \
# 300    s301    Movie  Action Replayy  Vipul Amrutlal Shah
#
#                                                   Cast Country  Release_Date  \
# 300  Akshay Kumar, Aishwarya Rai Bachchan, Om Puri,...   India  May 11, 2020
#
#     Rating Duration                                               Type  \
# 300  TV-PG  129 min  Children & Family Movies, Comedies, Internatio...
#
#                                            Description
# 300  Sick of his parents’ constant squabbling, a yo...

# %%
data[data['Title'].isin(['Aiyaary'])]
# Out:
#     Show_Id Category    Title       Director  \
# 355    s356    Movie  Aiyaary  Neeraj Pandey
#
#                                                   Cast Country  Release_Date  \
# 355  Sidharth Malhotra, Manoj Bajpayee, Rakul Preet...   India  May 15, 2018
#
#     Rating Duration                                              Type  \
# 355  TV-MA  158 min  Action & Adventure, Dramas, International Movies
#
#                                            Description
# 355  When his protégé goes rogue and poses a grave ...

# %%
data[data['Title'].isin(['Bhool Bhulaiya 2'])]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data[data['Title'].isin(['Ajab Prem Ki Ghazab Kahani'])]
# Out:
#     Show_Id Category                       Title           Director  \
# 358    s359    Movie  Ajab Prem Ki Ghazab Kahani  Rajkumar Santoshi
#
#                                                   Cast Country  \
# 358  Ranbir Kapoor, Katrina Kaif, Govind Namdeo, Da...   India
#
#          Release_Date Rating Duration  \
# 358  October 25, 2020  TV-14  150 min
#
#                                                  Type  \
# 358  Comedies, International Movies, Music & Musicals
#
#                                            Description
# 358  A young man's obsession with making others hap...

# %%
data[data['Title'].isin(['AK vs AK'])]
# Out:
#     Show_Id Category     Title              Director  \
# 362    s363    Movie  AK vs AK  Vikramaditya Motwane
#
#                             Cast Country       Release_Date Rating Duration  \
# 362  Anil Kapoor, Anurag Kashyap   India  December 25, 2020  TV-MA  109 min
#
#                                        Type  \
# 362  Comedies, Dramas, International Movies
#
#                                            Description
# 362  After a public spat with a movie star, a disgr...

# %%
data[data['Title'].isin(['Akbar Birbal'])]
# Out:
#     Show_Id Category         Title Director  \
# 364    s365  TV Show  Akbar Birbal      NaN
#
#                                           Cast Country    Release_Date Rating  \
# 364  Kiku Sharda, Vishal Kotian, Delnaaz Irani   India  March 31, 2020   TV-G
#
#      Duration                              Type  \
# 364  1 Season  Kids' TV, TV Comedies, TV Dramas
#
#                                            Description
# 364  From battles of wit to fights for justice, Emp...

# %%
data[data['Title'].isin(['Amar Akbar Anthony'])]
# Out:
#     Show_Id Category               Title        Director  \
# 446    s447    Movie  Amar Akbar Anthony  Manmohan Desai
#
#                                                   Cast Country  \
# 446  Vinod Khanna, Rishi Kapoor, Amitabh Bachchan, ...   India
#
#           Release_Date Rating Duration  \
# 446  December 31, 2019  TV-14  172 min
#
#                                              Type  \
# 446  Action & Adventure, Classic Movies, Comedies
#
#                                            Description
# 446  Abandoned in a park by their father, Amar, Akb...

# %%
data[data['Title'].isin(['Gangaajal'])]
# Out:
#      Show_Id Category      Title     Director  \
# 2349   s2350    Movie  Gangaajal  Prakash Jha
#
#                                                    Cast Country  \
# 2349  Ajay Devgn, Gracy Singh, Mohan Agashe, Mohan J...   India
#
#          Release_Date Rating Duration                          Type  \
# 2349  January 8, 2021  TV-MA  148 min  Dramas, International Movies
#
#                                             Description
# 2349  Posted to a small, crime-ridden town, a cop so...

# %%
data[data['Title'].isin(['Golmaal Returns'])]
# Out:
#      Show_Id Category            Title      Director  \
# 2470   s2471    Movie  Golmaal Returns  Rohit Shetty
#
#                                                    Cast Country  \
# 2470  Ajay Devgn, Kareena Kapoor, Arshad Warsi, Tuss...   India
#
#             Release_Date Rating Duration  \
# 2470  September 28, 2020  TV-MA  135 min
#
#                                                   Type  \
# 2470  Comedies, International Movies, Music & Musicals
#
#                                             Description
# 2470  A man's relationship with his jealous wife ent...

# %%
data[data['Title'].isin(['Golmaal: Fun Unlimited'])]
# Out:
#      Show_Id Category                   Title      Director  \
# 2471   s2472    Movie  Golmaal: Fun Unlimited  Rohit Shetty
#
#                                                    Cast Country  \
# 2471  Ajay Devgn, Tusshar Kapoor, Arshad Warsi, Shar...   India
#
#            Release_Date Rating Duration                            Type  \
# 2471  December 31, 2019  TV-14  148 min  Comedies, International Movies
#
#                                             Description
# 2471  Between thwarting crooks and wooing the belle ...

# %%
data[data['Title'].isin(['Bareilly Ki Barfi'])]
# Out:
#     Show_Id Category              Title             Director  \
# 751    s752    Movie  Bareilly Ki Barfi  Ashwiny Iyer Tiwari
#
#                                                   Cast Country  \
# 751  Ayushmann Khurrana, Kriti Sanon, Rajkummar Rao...   India
#
#         Release_Date Rating Duration                                    Type  \
# 751  August 21, 2018  TV-14  110 min  Comedies, Dramas, International Movies
#
#                                            Description
# 751  When she falls in love with the author of a no...

# %%
data[data['Title'].isin(['Chennai Express'])]
# Out:
#      Show_Id Category            Title      Director  \
# 1311   s1312    Movie  Chennai Express  Rohit Shetty
#
#                                                    Cast Country  \
# 1311  Shah Rukh Khan, Deepika Padukone, Nikitin Dhee...   India
#
#          Release_Date Rating Duration  \
# 1311  August 31, 2018  TV-14  135 min
#
#                                                    Type  \
# 1311  Action & Adventure, Comedies, International Mo...
#
#                                             Description
# 1311  What could have been a sad journey turns joyfu...

# %%
data[data['Title'].str.contains('Chennai Express')]
# Out:
#      Show_Id Category            Title      Director  \
# 1311   s1312    Movie  Chennai Express  Rohit Shetty
#
#                                                    Cast Country  \
# 1311  Shah Rukh Khan, Deepika Padukone, Nikitin Dhee...   India
#
#          Release_Date Rating Duration  \
# 1311  August 31, 2018  TV-14  135 min
#
#                                                    Type  \
# 1311  Action & Adventure, Comedies, International Mo...
#
#                                             Description
# 1311  What could have been a sad journey turns joyfu...

# %% [markdown]
# ### In which year highest number of TV shows and movies were released? Show with bar graph

# %%
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['Release_Date'])

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
# Visualization of the Data

data['Date_N'].dt.year.value_counts().plot(kind= 'bar',color='g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How many Movies & TV shows are in the dataset? Show with Bar Graph

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.groupby('Category')

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
# Copuntplot
sns.countplot(x='Category', data=data,palette='Greens')
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ### Show all the movies that were released in year 2000

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# #### Creating New Column

# %%
data['Year']=data['Date_N'].dt.year

# %%
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# #### Filtering

# %%
data['Category']=='Movie'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7784     True
# 7785     True
# 7786     True
# 7787    False
# 7788     True
# Name: Category, Length: 7787, dtype: bool

# %%
(data['Category']=='Movie')
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 7784     True
# 7785     True
# 7786     True
# 7787    False
# 7788     True
# Name: Category, Length: 7787, dtype: bool

# %%
(data['Category']=='Movie')&(data['Year']==2000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category']=='Movie')&(data['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# This shows that no movies were released in the year 2000

# %%
# Lets check for few other years
data[(data['Category']=='Movie')&(data['Year']==2015)]
# Out:
#      Show_Id Category                                              Title  \
# 128     s129    Movie                                            6 Years
# 247     s248    Movie                            A Very Murray Christmas
# 316     s317    Movie                                       Advantageous
# 535     s536    Movie                         Anjelah Johnson: Not Fancy
# 551     s552    Movie             Anthony Jeselnik: Thoughts and Prayers
# 648     s649    Movie          Aziz Ansari Live at Madison Square Garden
# 785     s786    Movie                                Beasts of No Nation
# 1013   s1014    Movie                                Bob's Broken Sleigh
# 1352   s1353    Movie                         Chris D'Elia: Incorrigible
# 1357   s1358    Movie                                  Chris Tucker Live
# 1394   s1395    Movie                                             Circle
# 1513   s1514    Movie              Cowspiracy: The Sustainability Secret
# ...

# %%
data[(data['Category']=='Movie')&(data['Year']==2010)]
# Out:
#      Show_Id Category                        Title    Director  \
# 3840   s3841    Movie  Mad Ron's Prevues from Hell  Jim Monaco
#
#                                                    Cast        Country  \
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#           Release_Date Rating Duration                        Type  \
# 3840  November 1, 2010     NR   84 min  Cult Movies, Horror Movies
#
#                                             Description     Date_N    Year
# 3840  This collection cherry-picks trailers, forgott... 2010-11-01  2010.0

# %%
data[(data['Category']=='Movie')&(data['Year']==2013)]
# Out:
#      Show_Id Category                        Title  \
# 220     s221    Movie   A Russell Peters Christmas
# 649     s650    Movie    Aziz Ansari: Buried Alive
# 2948   s2949    Movie  Iliza Shlesinger: War Paint
# 5315   s5315    Movie    Russell Peters: Notorious
# 5588   s5588    Movie            Shrek the Musical
# 6866   s6865    Movie               The Short Game
#
#                            Director  \
# 220              Henry Sarwer-Foner
# 649   Will Lovelace, Dylan Southern
# 2948                    Jay Chapman
# 5315                     Dave Higby
# 5588                    Jason Moore
# 6866                 Josh Greenbaum
#
#                                                    Cast        Country  \
# 220   Russell Peters, Pamela Anderson, Michael Bublé...         Canada
# 649                                         Aziz Ansari  United States
# 2948                                   Iliza Shlesinger  United States
# ...

# %%
data[(data['Category']=='Movie')&(data['Year']==2014)]
# Out:
#      Show_Id Category                                              Title  \
# 914     s915    Movie             Bill Burr: I'm Sorry You Feel That Way
# 1026   s1027    Movie  BoJack Horseman Christmas Special: Sabrina's C...
# 1309   s1310    Movie         Chelsea Handler: Uganda Be Kidding Me Live
# 1310   s1311    Movie                 Chelsea Peretti: One of the Greats
# 1902   s1903    Movie                                             E-Team
# 2294   s2295    Movie                        From One Second to the Next
# 2386   s2387    Movie                                          Get Santa
# 3057   s3058    Movie          Iron Man & Captain America: Heroes United
# 3966   s3967    Movie            Marvel's Iron Man & Hulk: Heroes United
# 4147   s4148    Movie                                       Mission Blue
# 4153   s4154    Movie                                               Mitt
# 4333   s4334    Movie      My Little Pony Equestria Girls: Rainbow Rocks
# ...

# %%
data[(data['Category']=='Movie')&(data['Year']==2019)]
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                    Oct-01
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %% [markdown]
# ### Shows only the titles of All TV Shows that were released in India only

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
(data['Category']=='TV Show')&(data['Country']=='India')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category']=='TV Show')&(data['Country']=='India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country  \
# ...

# %% [markdown]
# ### Movies of India

# %%
(data['Category']=='Movie')&(data['Country']=='India')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785     True
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category']=='Movie')&(data['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
data[(data['Category']=='Movie')&(data['Country']=='India')]['Title'] # Movies
# Out:
# 8                            706
# 9                           1920
# 18                        15-Aug
# 20          ​​Kuch Bheege Alfaaz
# 21                  ​Goli Soda 2
#                   ...
# 7766                        Zero
# 7771    Zindagi Na Milegi Dobara
# 7778                    Zokkomon
# 7782                         Zoo
# 7785                      Zubaan
# Name: Title, Length: 852, dtype: object

# %%
data[(data['Category']=='TV Show')&(data['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Show the Top 10 Directors who gave the highest number of TV shows and Movies

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Director'].value_counts()
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: Director, Length: 4050, dtype: int64

# %%
data['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ### Show all the records where Category is Movie and type is Comedies and country is India

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
(data['Category']=='Movie') & (data['Type']=='Comedies')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')|(data['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
data[(data['Category']=='Movie') & (data['Type']=='Comedies')|(data['Country']=='India')].head(60)
# Out:
#     Show_Id Category                                          Title  \
# 8        s9    Movie                                            706
# 9       s10    Movie                                           1920
# 18      s19    Movie                                         15-Aug
# 20      s21    Movie                           ​​Kuch Bheege Alfaaz
# 21      s22    Movie                                   ​Goli Soda 2
# 22      s23    Movie                             ​Maj Rati ​​Keteki
# 23      s24    Movie                                    ​Mayurakshi
# 33      s34    Movie                                   #realityhigh
# 59      s60    Movie                                1000 Rupee Note
# 72      s73    Movie                                       17 Again
# 78      s79    Movie                                       2 States
# 84      s85    Movie                                      21 & Over
# 86      s87  TV Show                   21 Sarfarosh: Saragarhi 1897
# ...

# %% [markdown]
# ### In how many movies Shah Rukh Khan was cast?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Cast']
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# 7788                                                  NaN
# Name: Cast, Length: 7787, dtype: object

# %%
data['Cast'] == 'Shah Rukh Khan'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Cast, Length: 7787, dtype: bool

# %%
data[data['Cast'] == 'Shah Rukh Khan']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# The above Code did not show the Shah Rukh Khan Entries because no cast is there where only SRK is mentioned

# %%
# Using STR Function
data['Cast']
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7784    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                              Nasty C
# 7787                           Adriano Zumbo, Rachel Khoo
# 7788                                                  NaN
# Name: Cast, Length: 7787, dtype: object

# %% [markdown]
# ### Create new DataFrame

# %%
data_new = data.dropna()

# %%
data_new.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
data_new[data_new['Cast'].str.contains('Shah Rukh Khan')]
# Out:
#      Show_Id Category                        Title            Director  \
# 599     s600    Movie                        Asoka       Santosh Sivan
# 926     s927    Movie                        Billu        Priyadarshan
# 1257   s1258    Movie                      Chaahat        Mahesh Bhatt
# 1265   s1266    Movie                Chalte Chalte          Aziz Mirza
# 1267   s1268    Movie                    Chamatkar         Rajiv Mehra
# 1311   s1312    Movie              Chennai Express        Rohit Shetty
# 1667   s1668    Movie                 Dear Zindagi        Gauri Shinde
# 1760   s1761    Movie                       Dil Se         Mani Ratnam
# 1764   s1765    Movie                      Dilwale        Rohit Shetty
# 1807   s1808    Movie                          Don       Farhan Akhtar
# 1808   s1809    Movie                        Don 2       Farhan Akhtar
# 1896   s1897    Movie                    Duplicate        Mahesh Bhatt
# ...

# %% [markdown]
# ### What are the different Ratings defined by Netflix

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data['Rating'].nunique()
# Out:
# 14

# %%
# Unique

data['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### How many movies got the TV-14 rating in India

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
(data['Category']=='Movie') & (data['Rating']=='TV-14')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785     True
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                    Oct-01      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')].shape
# Out:
# (1272, 13)

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')&(data['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# 22       s23    Movie        ​Maj Rati ​​Keteki   Santwana Bardoloi
# ...      ...      ...                       ...                 ...
# 7756   s7755    Movie                      Yuva         Mani Ratnam
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
data[(data['Category']=='Movie') & (data['Rating']=='TV-14')&(data['Country']=='India')].shape
# Out:
# (497, 13)

# %% [markdown]
# ### How many TV shows got the rating R after year 2018

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[(data['Category']=='TV Show')&(data['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_N    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
data[(data['Category']=='TV Show')&(data['Rating']=='R')&(data['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ### What is the maximum duration of a Movie/Show on  Netflix ?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.Duration.nunique()
# Out:
# 216

# %%
data.Duration.dtypes
# Out:
# dtype('O')

# %% [markdown]
# #### str.split

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[['Minutes','Unit']] = data['Duration'].str.split(' ',expand= True)

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# max()
data['Minutes']
# Out:
# 0         4
# 1        93
# 2        78
# 3        80
# 4       123
#        ...
# 7784     99
# 7785    111
# 7786     44
# 7787      1
# 7788     90
# Name: Minutes, Length: 7787, dtype: object

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data['Minutes'].mean()
# Out:
# inf

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %% [markdown]
# ### Which individual country has the Highest Number of TV Shows?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data_tvshow = data[data['Category']=='TV Show']

# %%
data_tvshow
# Out:
#      Show_Id Category                  Title              Director  \
# 0         s1  TV Show                     3%                   NaN
# 5         s6  TV Show                     46           Serdar Akar
# 11       s12  TV Show                   1983                   NaN
# 12       s13  TV Show                   1994  Diego Enrique Osorno
# 16       s17  TV Show                 Feb-09                   NaN
# ...      ...      ...                    ...                   ...
# 7769   s7768  TV Show     Zindagi Gulzar Hai                   NaN
# 7777   s7776  TV Show             Zoids Wild                   NaN
# 7779   s7778  TV Show            Zombie Dumb                   NaN
# 7781   s7780  TV Show              Zona Rosa                   NaN
# 7787   s7786  TV Show  Zumbo's Just Desserts                   NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data_tvshow.Country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(10)
# Out:
# United States     705
# United Kingdom    204
# Japan             157
# South Korea       147
# India              71
# Taiwan             68
# Canada             59
# France             46
# Australia          46
# Spain              45
# Name: Country, dtype: int64

# %% [markdown]
# ### How can we sort the Dataset by year ?

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.sort_values(by='Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by='Year',ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %%
data.sort_values(by='Year',ascending=True)
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
data.sort_values(by='Year',ascending=False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 2799   s2800    Movie                                               Hook
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 5955               Aamir Khan
# ...

# %%
data.sort_values(by='Year',ascending=True).head(10)
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
# 6847   s6846    Movie         The Ryan White Story         John Herzfeld
# 308     s309    Movie     Adam: His Song Continues      Robert Markowitz
# 7416   s7415    Movie             Victim of Beauty           Roger Young
# 7232   s7231    Movie         Triumph of the Heart      Richard Michaels
# 7364   s7363    Movie             Unspeakable Acts            Linda Otto
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# ...

# %% [markdown]
# # Find all the isntances where

# %% [markdown]
# ### Category is 'Movie' and type is 'Dramas'

# %% [markdown]
# ## OR

# %% [markdown]
# ### Category is 'TV 📺 Show' and type is 'Kids'

# %%
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data[(data['Category']=='Movie')&(data['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data['Category']=='Movie')&(data['Type']=='Dramas')].head(20)
# Out:
#      Show_Id Category                           Title            Director  \
# 4         s5    Movie                              21      Robert Luketic
# 7         s8    Movie                             187      Kevin Reynolds
# 170     s171    Movie                    A Family Man       Mark Williams
# 232     s233    Movie      A Stoning in Fulham County       Larry Elikann
# 295     s296    Movie              Across Grace Alley       Ralph Macchio
# 308     s309    Movie        Adam: His Song Continues    Robert Markowitz
# 330     s331    Movie                       Aftermath      Elliott Lester
# 334     s335    Movie  Agatha and the Truth of Murder         Terry Loane
# 422     s423    Movie                All Together Now         Brett Haley
# 429     s430    Movie                 Alone in Berlin       Vincent Perez
# 455     s456    Movie                 American Beauty          Sam Mendes
# 466     s467    Movie              American History X           Tony Kaye
# ...

# %%
(data['Category']=='TV Show')&(data['Type']=="Kids TV")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7787, dtype: bool

# %%
data[ (data['Category']=='TV Show')&(data['Type']=="Kids' TV") ]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...
